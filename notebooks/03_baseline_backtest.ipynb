# %% [markdown]
# # 03 Baseline Backtest
#
# Local notebook focused on baseline strategies and walk-forward outputs.

# %%
from pathlib import Path
import subprocess, sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent
CFG = PROJECT_ROOT / 'configs' / 'default.yaml'
print(PROJECT_ROOT)
# Out:
# C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer

# %%
cmd = [sys.executable, str(PROJECT_ROOT / 'src' / 'walk_forward.py'), '--config', str(CFG)]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
print('Done walk-forward.')
# Out:
# Running: c:\Users\votranhuonggiang\AppData\Local\Programs\Python\Python311\python.exe C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer\src\walk_forward.py --config C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer\configs\default.yaml
# Done walk-forward.

# %%
wf = pd.read_csv(PROJECT_ROOT / 'outputs' / 'metrics' / 'walk_forward_results.csv')
print(wf.head())    
print('models:', sorted(wf['model'].unique()))
# Out:
#    total_return  annualized_return  annualized_volatility  sharpe_ratio  \
# 0     -0.115163          -0.665261               0.367420     -2.978595
# 1     -0.009762          -0.031482               0.350046     -0.091381
# 2     -0.003161           0.034728               0.358595      0.095202
# 3      0.037413           0.510514               0.356951      1.155485
# 4     -0.011924          -0.046889               0.363262     -0.132201
#
#    sortino_ratio  max_drawdown  calmar_ratio  hit_rate  profit_factor  \
# 0      -3.455043     -0.152689     -4.356981  0.465105       0.749259
# 1      -0.130376     -0.093121     -0.338071  0.391284       0.146059
# 2       0.134400     -0.136577      0.254277  0.404467       0.161775
# 3       1.605093     -0.062850      8.122695  0.428970       0.254942
# 4      -0.180463     -0.086116     -0.544487  0.444169       0.266601
#
#    average_trade_pnl  average_win  average_loss  win_loss_ratio  \
# 0          -0.169051     2.068722     -0.892023        2.319135
# 1          -0.762308     1.437146     -0.981765        1.463838
# 2          -0.738012     1.426760     -0.978090        1.458721
# 3          -0.695846     1.951411     -1.063742        1.834477
# 4          -0.638351     1.788608     -1.000159        1.788324
#
#    number_of_trades  turnover                      window      model
# 0               258     258.0  wf_1_2021-07-01_2021-12-31  long_only
# 1              1488    1488.0  wf_1_2021-07-01_2021-12-31   tsmom_12
# 2              1182    1182.0  wf_1_2021-07-01_2021-12-31   tsmom_24
# 3               754     754.0  wf_1_2021-07-01_2021-12-31   tsmom_48
# 4               686     686.0  wf_1_2021-07-01_2021-12-31   tsmom_78
# models: ['decoder_tft', 'decoder_transformer', 'ema_cross_16_48', 'ema_cross_32_96', 'ema_cross_8_24', 'long_only', 'lstm_dmn', 'macd_16_48', 'macd_32_96', 'macd_8_24', 'tsmom_12', 'tsmom_24', 'tsmom_48', 'tsmom_78']

# %%
model_cmp = pd.read_csv(PROJECT_ROOT / 'outputs' / 'tables' / 'model_comparison_metrics.csv')
display(model_cmp.sort_values('sharpe_ratio', ascending=False))
# Out:
#                   model  total_return  sharpe_ratio  max_drawdown  \
# 0       ema_cross_32_96      0.835964      1.825838     -0.168122
# 1            macd_32_96      0.835964      1.825838     -0.168122
# 2             macd_8_24      0.146935      0.562188     -0.366673
# 3        ema_cross_8_24      0.146935      0.562188     -0.366673
# 4              tsmom_78     -0.134437     -0.206628     -0.313299
# 5       ema_cross_16_48     -0.206370     -0.440085     -0.354431
# 6            macd_16_48     -0.206370     -0.440085     -0.354431
# 7              tsmom_12     -0.289595     -0.779933     -0.536621
# 8             long_only     -0.430239     -1.318088     -0.555921
# 9              tsmom_48     -0.434911     -1.393664     -0.587254
# 10             lstm_dmn     -0.028366     -1.451961     -0.042211
# 11          decoder_tft     -0.362265     -2.136414     -0.427343
# 12             tsmom_24     -0.592683     -2.317536     -0.675643
# 13  decoder_transformer     -0.355158     -2.355658     -0.393768
#
#     profit_factor
# 0        0.625182
# 1        0.625182
# 2        0.229919
# 3        0.229919
# 4        0.256740
# 5        0.377426
# 6        0.377426
# 7        0.128035
# 8        0.760118
# 9        0.211501
# 10       0.931059
# 11       0.967332
# 12       0.146867
# 13       0.963096
