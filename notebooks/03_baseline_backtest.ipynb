# %% [markdown]
# # 03 Baseline Backtest
#
# Local notebook focused on baseline strategies and walk-forward outputs.

# %%
from pathlib import Path
import subprocess, sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent
CFG = PROJECT_ROOT / 'configs' / 'default.yaml'
print(PROJECT_ROOT)
# Out:
# C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer

# %%
cmd = [sys.executable, str(PROJECT_ROOT / 'src' / 'walk_forward.py'), '--config', str(CFG)]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
print('Done walk-forward.')
# Out:
# Running: c:\Users\votranhuonggiang\AppData\Local\Programs\Python\Python311\python.exe C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer\src\walk_forward.py --config C:\Users\votranhuonggiang\OneDrive\ドキュメント\Python\MiQuant\Training\MomentumTransformer\vn30f1m_momentum_transformer\configs\default.yaml
# Done walk-forward.

# %%
wf = pd.read_csv(PROJECT_ROOT / 'outputs' / 'metrics' / 'walk_forward_results.csv')
print(wf.head())
print('models:', sorted(wf['model'].unique()))
# Out:
#    total_return  annualized_return  annualized_volatility  sharpe_ratio  \
# 0     -0.103929          -0.622654               0.367392     -2.652714
# 1      0.069970           1.034632               0.369125      1.924333
# 2      0.028245           0.394203               0.368481      0.901874
# 3      0.077842           1.180460               0.368061      2.117969
# 4     -0.024917          -0.157982               0.368119     -0.467116
#
#    sortino_ratio  max_drawdown  calmar_ratio  hit_rate  profit_factor  \
# 0      -3.077965     -0.142683     -4.363900  0.465881       0.848448
# 1       2.759493     -0.080489     12.854249  0.432382       0.153511
# 2       1.280960     -0.133011      2.963683  0.435174       0.163444
# 3       2.977359     -0.073166     16.134027  0.448046       0.269764
# 4      -0.636304     -0.093161     -1.695799  0.458902       0.246410
#
#    average_trade_pnl  average_win  average_loss  win_loss_ratio  \
# 0          -0.096512     2.144615     -0.851295        2.519238
# 1          -1.135072     1.370659     -1.577884        0.868669
# 2          -1.070957     1.211465     -1.547473        0.782866
# 3          -0.937255     1.842609     -1.580483        1.165852
# 4          -0.919646     1.618095     -1.498913        1.079512
#
#    number_of_trades  turnover                      window      model
# 0               258     258.0  wf_1_2021-07-01_2021-12-31  long_only
# 1              1112    1846.0  wf_1_2021-07-01_2021-12-31   tsmom_12
# 2               909    1486.0  wf_1_2021-07-01_2021-12-31   tsmom_24
# 3               612     922.0  wf_1_2021-07-01_2021-12-31   tsmom_48
# 4               565     840.0  wf_1_2021-07-01_2021-12-31   tsmom_78
# models: ['decoder_tft', 'decoder_transformer', 'ema_cross_16_48', 'ema_cross_32_96', 'ema_cross_8_24', 'long_only', 'lstm_dmn', 'macd_16_48', 'macd_32_96', 'macd_8_24', 'tsmom_12', 'tsmom_24', 'tsmom_48', 'tsmom_78']

# %%
model_cmp = pd.read_csv(PROJECT_ROOT / 'outputs' / 'tables' / 'model_comparison_metrics.csv')
display(model_cmp.sort_values('sharpe_ratio', ascending=False))
# Out:
#                   model  total_return  sharpe_ratio  max_drawdown  \
# 0        ema_cross_8_24      0.090860      2.427744     -0.078151
# 1             macd_8_24      0.090860      2.427744     -0.078151
# 2              tsmom_48      0.077842      2.117969     -0.073166
# 3              tsmom_12      0.069970      1.924333     -0.080489
# 4              tsmom_24      0.028245      0.901874     -0.133011
# 5       ema_cross_16_48      0.003852      0.282887     -0.101813
# 6            macd_16_48      0.003852      0.282887     -0.101813
# 7              lstm_dmn      0.000000      0.000000      0.000000
# 8            macd_32_96     -0.024566     -0.459869     -0.101183
# 9       ema_cross_32_96     -0.024566     -0.459869     -0.101183
# 10             tsmom_78     -0.024917     -0.467116     -0.093161
# 11          decoder_tft     -0.037469     -2.003759     -0.057022
# 12            long_only     -0.103929     -2.652714     -0.142683
# 13  decoder_transformer     -0.113936     -3.018465     -0.142393
#
#     profit_factor
# 0        0.268297
# 1        0.268297
# 2        0.269764
# 3        0.153511
# 4        0.163444
# 5        0.444706
# 6        0.444706
# 7        0.000000
# 8        0.776945
# 9        0.776945
# 10       0.246410
# 11       0.970203
# 12       0.848448
# 13       0.957541
